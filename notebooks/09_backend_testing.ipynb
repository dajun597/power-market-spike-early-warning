# %%
from src.backend.model_prediction import SpikePredictor
from src.features.feature_engineer import spike_feature
import pandas as pd

# %%
df=pd.read_csv('../data/processed/dashboard_dataset.csv')
# df=spike_feature(df)
# print(df.head(10))
# print(df.columns)

# %%
from src.backend.model_prediction import SpikePredictor

# %%
spike=SpikePredictor()
spike.predict(df)
# Out:
#        demand_prediction  NetImbalanceVolume  ccgt_wind_ratio  imbalance_ccgt  \
# 0           26212.619375          422.922700              NaN             NaN
# 1           25626.780000          244.143750         3.569644        0.023095
# 2           24930.148750           90.218100         3.681477        0.008962
# 3           24505.156250          253.595250         4.172138        0.024942
# 4           25443.458750          211.544950         5.263716        0.020802
# ...                  ...                 ...              ...             ...
# 87486       33402.640625          157.382567         0.905169        0.012022
# 87487       30568.987500          -87.644851         0.704552       -0.008685
# 87488       27644.492500          -40.465514         0.552488       -0.005321
# 87489       25068.958750           70.337433         0.497146        0.010420
# 87490       23398.881875          -40.384207         0.480909       -0.006096
#
#         ps_imbalance  offer_bid_spread  month                 time  is_spike  \
# 0                NaN        434.667950      1  2016-01-08 01:00:00         1
# 1     -411382.218750        246.110200      1  2016-01-08 02:00:00         0
# 2     -149401.173600        274.383500      1  2016-01-08 03:00:00         0
# 3     -418939.353000        427.294850      1  2016-01-08 04:00:00         0
# 4     -378030.825650        212.554950      1  2016-01-08 05:00:00         0
# ...              ...               ...    ...                  ...       ...
# 87486   -6610.067808       6788.526833     12  2025-12-31 19:00:00         1
# 87487   26118.165580       6903.177894     12  2025-12-31 20:00:00         0
# 87488   11168.481959       7029.779673     12  2025-12-31 21:00:00         0
# 87489  -10058.252888       7178.997982     12  2025-12-31 22:00:00         0
# 87490   12074.877839       7192.882399     12  2025-12-31 23:00:00         0
#
#        CCGT_lag_1  INTIRL_lag_1  NPSHYD_lag_1  OCGT_lag_1  OTHER_lag_1  \
# 0             NaN           NaN           NaN         NaN          NaN
# 1         10571.5         170.0         553.5         0.0       2092.0
# 2         10067.0         164.0         551.5         0.0       2095.0
# 3         10167.5         138.0         550.0         0.0       2090.5
# 4         10169.5         102.0         547.5         0.0       2094.5
# ...           ...           ...           ...         ...          ...
# 87486     13091.0        -452.0         578.5         6.0        678.5
# 87487     10092.0        -452.0         494.0         6.5        601.5
# 87488      7605.0        -452.0         451.0         2.5        410.0
# 87489      6750.5        -390.0         376.5         2.0        776.5
# 87490      6625.0        -443.0         354.0         2.5        338.0
#
#        PS_lag_1  WIND_lag_1  TotalAcceptedBidVolume_lag_1  spike_precentage  \
# 0           NaN         NaN                           NaN          0.221986
# 1       -1685.0      2961.5                     -5.333450          0.180496
# 2       -1656.0      2734.5                     -0.733400          0.103227
# 3       -1652.0      2437.0                    -91.920850          0.177640
# 4       -1787.0      1932.0                    -86.746100          0.180284
# ...         ...         ...                           ...               ...
# 87486     -42.0     14462.5                  -2981.373918          0.247276
# 87487    -298.0     14324.0                  -3465.773886          0.010034
# 87488    -276.0     13765.0                  -3616.335362          0.011791
# 87489    -143.0     13578.5                  -3638.079364          0.100157
# 87490    -299.0     13776.0                  -3582.789493          0.010210
#
#       risk_level
# 0         medium
# 1       moderate
# 2       moderate
# 3       moderate
# 4       moderate
# ...          ...
# 87486     medium
# 87487        low
# 87488        low
# 87489   moderate
# 87490        low
#
# [87464 rows x 19 columns]
